# %%
from nltk.corpus import wordnet as wn

def get_meronym_tree_data(synset_id, nodes=None, edges=None, visited=None, depth=0):
    """
    Recursively builds a meronym tree from the given synset.
    Includes part, member, and substance meronyms.
    """
    if nodes is None:
        nodes = []
    if edges is None:
        edges = []
    if visited is None:
        visited = set()

    if synset_id in visited:
        return nodes, edges

    visited.add(synset_id)
    synset = wn.synset(synset_id)

    # Add current node
    nodes.append({
        'data': {
            'id': synset_id,
            'label': synset_id,
            'definition': synset.definition(),
            'depth': depth
        }
    })

    # Explore all types of meronyms
    meronym_types = [
        ("part_meronyms", synset.part_meronyms()),
        ("member_meronyms", synset.member_meronyms()),
        ("substance_meronyms", synset.substance_meronyms())
    ]

    for label, meronyms in meronym_types:
        for meronym in meronyms:
            meronym_id = meronym.name()
            edges.append({
                'data': {
                    'source': synset_id,
                    'target': meronym_id,
                    'label': label.replace("_", " ")
                }
            })
            get_meronym_tree_data(meronym_id, nodes, edges, visited, depth + 1)

    return nodes + edges


def get_meronym_tree_data_text(synset_name):
    """
    Recursively builds a meronym tree as text (indented format).
    Includes part, member, and substance meronyms.
    """
    tree_text = ""

    def recurse(synset_name, depth=0):
        nonlocal tree_text
        synset = wn.synset(synset_name)
        indent = "  " * depth
        tree_text += f"{indent}↳ {synset.name()} ({synset.definition()})\n"

        # Define types of meronyms
        meronym_types = [
            ("part", synset.part_meronyms()),
            ("member", synset.member_meronyms()),
            ("substance", synset.substance_meronyms())
        ]

        for relation, meronyms in meronym_types:
            for meronym in meronyms:
                recurse(meronym.name(), depth + 1)

    recurse(synset_name)
    return tree_text
# Out:
# [{'data': {'id': 'car.n.01', 'label': 'car.n.01', 'definition': 'a motor vehicle with four wheels; usually propelled by an internal combustion engine', 'depth': 0}}, {'data': {'id': 'roof.n.02', 'label': 'roof.n.02', 'definition': 'protective covering on top of a motor vehicle', 'depth': 1}}, {'data': {'id': 'gasoline_engine.n.01', 'label': 'gasoline_engine.n.01', 'definition': 'an internal-combustion engine that burns gasoline; most automobiles are driven by gasoline engines', 'depth': 1}}, {'data': {'id': 'inlet_manifold.n.01', 'label': 'inlet_manifold.n.01', 'definition': 'manifold that carries vaporized fuel from the carburetor to the inlet valves of the cylinders', 'depth': 2}}, {'data': {'id': 'auto_accessory.n.01', 'label': 'auto_accessory.n.01', 'definition': 'an accessory for an automobile', 'depth': 1}}, {'data': {'id': 'sunroof.n.01', 'label': 'sunroof.n.01', 'definition': 'an automobile roof having a sliding or raisable panel', 'depth': 1}}, {'data': {'id': 'automobile_horn.n.01', 'label': 'automobile_horn.n.01', 'definition': 'a device on an automobile for making a warning noise', 'depth': 1}}, {'data': {'id': 'horn_button.n.01', 'label': 'horn_button.n.01', 'definition': 'a button that you press to activate the horn of an automobile', 'depth': 2}}, {'data': {'id': 'rear_window.n.01', 'label': 'rear_window.n.01', 'definition': 'car window that allows vision out of the back of the car', 'depth': 1}}, {'data': {'id': 'buffer.n.06', 'label': 'buffer.n.06', 'definition': 'a cushion-like device that reduces shock due to an impact', 'depth': 1}}, {'data': {'id': 'fender.n.01', 'label': 'fender.n.01', 'definition': 'a barrier that surrounds the wheels of a vehicle to block splashing water or mud', 'depth': 1}}, {'data': {'id': 'glove_compartment.n.01', 'label': 'glove_compartment.n.01', 'definition': 'compartment on the dashboard of a car', 'depth': 1}}, {'data': {'id': 'car_window.n.01', 'label': 'car_window.n.01', 'definition': 'a window in a car', 'depth': 1}}, {'data': {'id': 'floorboard.n.02', 'label': 'floorboard.n.02', 'definition': 'the floor of an automobile', 'depth': 1}}, {'data': {'id': 'accelerator.n.01', 'label': 'accelerator.n.01', 'definition': 'a pedal that controls the throttle valve', 'depth': 1}}, {'data': {'id': 'grille.n.02', 'label': 'grille.n.02', 'definition': "grating that admits cooling air to car's radiator", 'depth': 1}}, {'data': {'id': 'car_mirror.n.01', 'label': 'car_mirror.n.01', 'definition': 'a mirror that the driver of a car can use', 'depth': 1}}, {'data': {'id': 'first_gear.n.01', 'label': 'first_gear.n.01', 'definition': 'the lowest forward gear ratio in the gear box of a motor vehicle; used to start a car moving', 'depth': 1}}, {'data': {'id': 'reverse.n.02', 'label': 'reverse.n.02', 'definition': 'the gears by which the motion of a machine can be reversed', 'depth': 1}}, {'data': {'id': 'stabilizer_bar.n.01', 'label': 'stabilizer_bar.n.01', 'definition': 'a rigid metal bar between the front suspensions and between the rear suspensions of cars and trucks; serves to stabilize the chassis', 'depth': 1}}, {'data': {'id': 'bumper.n.02', 'label': 'bumper.n.02', 'definition': 'a mechanical device consisting of bars at either end of a vehicle to absorb shock and prevent serious damage', 'depth': 1}}, {'data': {'id': 'bumper_guard.n.01', 'label': 'bumper_guard.n.01', 'definition': 'vertical bars attached to a bumper to prevent locking bumpers with another vehicle', 'depth': 2}}, {'data': {'id': 'car_door.n.01', 'label': 'car_door.n.01', 'definition': 'the door of a car', 'depth': 1}}, {'data': {'id': 'armrest.n.01', 'label': 'armrest.n.01', 'definition': 'a support for the arm', 'depth': 2}}, {'data': {'id': 'doorlock.n.01', 'label': 'doorlock.n.01', 'definition': 'a lock on an exterior door', 'depth': 2}}, {'data': {'id': 'hinge.n.01', 'label': 'hinge.n.01', 'definition': 'a joint that holds two parts together so that one can swing relative to the other', 'depth': 2}}, {'data': {'id': 'pi ...
# ↳ car.n.01 (a motor vehicle with four wheels; usually propelled by an internal combustion engine)
#   ↳ roof.n.02 (protective covering on top of a motor vehicle)
#   ↳ gasoline_engine.n.01 (an internal-combustion engine that burns gasoline; most automobiles are driven by gasoline engines)
#     ↳ inlet_manifold.n.01 (manifold that carries vaporized fuel from the carburetor to the inlet valves of the cylinders)
#   ↳ auto_accessory.n.01 (an accessory for an automobile)
#   ↳ sunroof.n.01 (an automobile roof having a sliding or raisable panel)
#   ↳ automobile_horn.n.01 (a device on an automobile for making a warning noise)
#     ↳ horn_button.n.01 (a button that you press to activate the horn of an automobile)
#   ↳ rear_window.n.01 (car window that allows vision out of the back of the car)
#   ↳ buffer.n.06 (a cushion-like device that reduces shock due to an impact)
#   ↳ fender.n.01 (a barrier that surrounds the wheels of a vehicle to block splashing water or mud)
#   ↳ glove_compartment.n.01 (compartment on the dashboard of a car)
#   ↳ car_window.n.01 (a window in a car)
#   ↳ floorboard.n.02 (the floor of an automobile)
#   ↳ accelerator.n.01 (a pedal that controls the throttle valve)
#   ↳ grille.n.02 (grating that admits cooling air to car's radiator)
#   ↳ car_mirror.n.01 (a mirror that the driver of a car can use)
#   ↳ first_gear.n.01 (the lowest forward gear ratio in the gear box of a motor vehicle; used to start a car moving)
#   ↳ reverse.n.02 (the gears by which the motion of a machine can be reversed)
#   ↳ stabilizer_bar.n.01 (a rigid metal bar between the front suspensions and between the rear suspensions of cars and trucks; serves to stabilize the chassis)
#   ↳ bumper.n.02 (a mechanical device consisting of bars at either end of a vehicle to absorb shock and prevent serious damage)
#     ↳ bumper_guard.n.01 (vertical bars attached to a bumper to prevent locking bumpers with another vehicle)
#   ↳ car_door.n.01 (the door of a car)
#     ↳ armrest.n.01 (a support for the arm)
#     ↳ doorlock.n.01 (a lock on an exterior door)
#     ↳ hinge.n.01 (a joint that holds two parts together so that one can swing relative to the other)
#       ↳ pintle.n.01 (a pin or bolt forming the pivot of a hinge)
#   ↳ car_seat.n.01 (a seat in a car)
#     ↳ back.n.08 (a support that you can lean against while sitting)
#     ↳ headrest.n.01 (a cushion attached to the top of the back of an automobile's seat to prevent whiplash)
#     ↳ seat_belt.n.01 (a safety belt used in a car or plane to hold you in your seat in case of an accident)
#   ↳ high_gear.n.01 (a forward gear with a gear ratio that gives the greatest vehicle velocity for a given engine speed)
#   ↳ window.n.02 (a transparent opening in a vehicle that allow vision out of the sides or back; usually is capable of being opened)
#   ↳ tail_fin.n.02 (one of a pair of decorations projecting above the rear fenders of an automobile)
#   ↳ third_gear.n.01 (the third from the lowest forward ratio gear in the gear box of a motor vehicle)
#   ↳ running_board.n.01 (a narrow footboard serving as a step beneath the doors of some old cars)
#   ↳ hood.n.09 (protective covering consisting of a metal part that covers the engine)
#     ↳ hood_ornament.n.01 (an ornament on the front of the hood of a car emblematic of the manufacturer)
#   ↳ luggage_compartment.n.01 (compartment in an automobile that carries luggage or shopping or tools)
#   ↳ air_bag.n.01 (a safety restraint in an automobile; the bag inflates on collision and prevents the driver or passenger from being thrown forward)
#   ↳ automobile_engine.n.01 (the engine that propels an automobile)
#     ↳ exhaust.n.02 (system consisting of the parts of an engine through which burned gases or steam are discharged)
#       ↳ exhaust_valve.n.01 (a valve through which burned gases from a cylinder escape into the exhaust manifold)
#       ↳ exhaust_manifold.n.01 (a manifold that receives exhaust gases from the cylinders and conducts them to the exhaust pipe)
#       ↳ tailpipe.n.01 (a pipe carrying fumes from the muffler to the rear of a car)
#       ↳ exhaust_pipe.n.01 (a pipe through which burned gases travel from the exhaust manifold to the muffler)
#       ↳ silencer.n.02 (a tubular acoustic device inserted in the exhaust system that is designed to reduce noise)
